# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
run report_plots.py
# Out:
# [29.64,
#  27.19,
#  45.9,
#  37.45,
#  34.33,
#  32.92,
#  35.17,
#  27.4,
#  43.1,
#  41.82,
#  45.6,
#  59.57,
#  58.14,
#  69.67,
#  77.67,
#  80.57,
#  87.67,
#  93.4,
#  77.17,
#  49.11,
#  72.5,
#  70.5,
#  124.25,
#  93.6,
#  124.75,
#  87.4,
#  99.4,
#  61.43,
#  70.5,
#  45.44,
#  48.78,
#  42.6,
#  42.7,
#  43.4,
#  40.09,
#  56.56,
#  71.83,
#  58.43,
#  67.33,
#  66.29,
#  97.4,
#  116.25,
#  121.5,
#  161.67,
#  154.67,
#  178.0,
#  161.67,
#  139.5,
#  113.5,
#  96.4,
#  119.75,
#  57.57,
#  43.3,
#  40.8,
#  48.8,
#  53.78,
#  45.56,
#  77.83,
#  73.0,
#  57.43,
#  67.67,
#  65.43,
#  107.5,
#  128.5,
#  114.75,
#  135.33,
#  139.67,
#  152.67,
#  192.0,
#  193.67,
#  193.0,
#  172.33,
#  187.67,
#  200.0,
#  190.67,
#  189.33,
#  192.0,
#  170.0,
#  154.0,
#  143.75,
#  134.33,
#  118.75,
#  116.0,
#  94.4,
#  92.6,
#  99.0,
#  113.5,
#  98.0,
#  128.75,
#  102.6,
#  135.25,
#  143.33,
#  133.33,
#  184.33,
#  161.67,
#  162.33,
#  200.0,
#  200.0,
#  200.0,
# ...
